# %%
import pandas as pd
import numpy as np

# %%
df_ted = pd.read_csv('ted_main.csv')

# %%
df_ted.tail(5)
# Out:
#       comments                                        description  duration  \
# 2545        17  Between 2008 and 2016, the United States depor...       476
# 2546         6  How can you study Mars without a spaceship? He...       290
# 2547        10  Science fiction visions of the future show us ...       651
# 2548        32  In an unmissable talk about race and politics ...      1100
# 2549         8  With more than half of the world population li...       519
#
#              event   film_date  languages         main_speaker  \
# 2545       TED2017  1496707200          4     Duarte Geraldino
# 2546       TED2017  1492992000          3  Armando Azua-Bustos
# 2547       TED2017  1492992000          1       Radhika Nagpal
# 2548  TEDxMileHigh  1499472000          1     Theo E.J. Wilson
# 2549       TED2017  1492992000          1    Karoliina Korppoo
#
#                                                    name  num_speaker  \
# ...

# %%
df_ted.isnull().sum()
# Out:
# comments              0
# description           0
# duration              0
# event                 0
# film_date             0
# languages             0
# main_speaker          0
# name                  0
# num_speaker           0
# published_date        0
# ratings               0
# related_talks         0
# speaker_occupation    6
# tags                  0
# title                 0
# url                   0
# views                 0
# dtype: int64

# %%
#there are 6 speakers with unknown occupation. Other than that, the dataset is super clean. Kaggle is spoiling us

# %%
#time to see data types
df_ted.dtypes
# Out:
# comments               int64
# description           object
# duration               int64
# event                 object
# film_date              int64
# languages              int64
# main_speaker          object
# name                  object
# num_speaker            int64
# published_date         int64
# ratings               object
# related_talks         object
# speaker_occupation    object
# tags                  object
# title                 object
# url                   object
# views                  int64
# dtype: object

# %%
#now time to change date type
import datetime as dt
df_ted['film_date']=df_ted['film_date'].dt.date
df_ted['published_date'] = df_ted['published_date'].dt.date

# %%
df_ted.tail(3)
# Out:
#       comments                                        description  duration  \
# 2547        10  Science fiction visions of the future show us ...       651
# 2548        32  In an unmissable talk about race and politics ...      1100
# 2549         8  With more than half of the world population li...       519
#
#              event   film_date  languages       main_speaker  \
# 2547       TED2017  1970-01-01          1     Radhika Nagpal
# 2548  TEDxMileHigh  1970-01-01          1   Theo E.J. Wilson
# 2549       TED2017  1970-01-01          1  Karoliina Korppoo
#
#                                                    name  num_speaker  \
# 2547  Radhika Nagpal: What intelligent machines can ...            1
# 2548  Theo E.J. Wilson: A black man goes undercover ...            1
# 2549  Karoliina Korppoo: How a video game might help...            1
#
#      published_date                                            ratings  \
# ...

# %%
import seaborn as sns
import matplotlib as mpl

# %%
df_ted.columns
# Out:
# Index(['comments', 'description', 'duration', 'event', 'film_date',
#        'languages', 'main_speaker', 'name', 'num_speaker', 'published_date',
#        'ratings', 'related_talks', 'speaker_occupation', 'tags', 'title',
#        'url', 'views'],
#       dtype='object')

# %%
#visualize barplot: porpular speakers by their best speech
graph_1 = sns.barplot(y='main_speaker',  x='views', data =df_ted.sort_values('views', ascending = False) [:20] )

# %%
df_ted.ratings [:10]
# Out:
# 0    [{'id': 7, 'name': 'Funny', 'count': 19645}, {...
# 1    [{'id': 7, 'name': 'Funny', 'count': 544}, {'i...
# 2    [{'id': 7, 'name': 'Funny', 'count': 964}, {'i...
# 3    [{'id': 3, 'name': 'Courageous', 'count': 760}...
# 4    [{'id': 9, 'name': 'Ingenious', 'count': 3202}...
# 5    [{'id': 7, 'name': 'Funny', 'count': 1102}, {'...
# 6    [{'id': 3, 'name': 'Courageous', 'count': 477}...
# 7    [{'id': 9, 'name': 'Ingenious', 'count': 195},...
# 8    [{'id': 3, 'name': 'Courageous', 'count': 562}...
# 9    [{'id': 21, 'name': 'Unconvincing', 'count': 8...
# Name: ratings, dtype: object

# %%
df_ted['main_speaker'].value_counts()[:10]
# Out:
# Hans Rosling            9
# Juan Enriquez           7
# Marco Tempest           6
# Rives                   6
# Jacqueline Novogratz    5
# Julian Treasure         5
# Nicholas Negroponte     5
# Bill Gates              5
# Clay Shirky             5
# Dan Ariely              5
# Name: main_speaker, dtype: int64

# %%
df_ted['total_view']= df_ted.groupby('main_speaker')['views'].sum()

# %%
df_ted.tail(5)
# Out:
#       comments                                        description  duration  \
# 2545        17  Between 2008 and 2016, the United States depor...       476
# 2546         6  How can you study Mars without a spaceship? He...       290
# 2547        10  Science fiction visions of the future show us ...       651
# 2548        32  In an unmissable talk about race and politics ...      1100
# 2549         8  With more than half of the world population li...       519
#
#              event   film_date  languages         main_speaker  \
# 2545       TED2017  1496707200          4     Duarte Geraldino
# 2546       TED2017  1492992000          3  Armando Azua-Bustos
# 2547       TED2017  1492992000          1       Radhika Nagpal
# 2548  TEDxMileHigh  1499472000          1     Theo E.J. Wilson
# 2549       TED2017  1492992000          1    Karoliina Korppoo
#
#                                                    name  num_speaker  \
# ...

# %%
df_ted_2 = df_ted.groupby('main_speaker')['views'].sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-70c8899edfa9> in <module>()
# ----> 1 df_ted_2 = pd.df_ted.groupby('main_speaker')['views'].sum()
#
# AttributeError: module 'pandas' has no attribute 'df_ted'

# %%
type(df_ted_2)
# Out:
# pandas.core.series.Series

# %%
df_ted_2= pd.DataFrame(df_ted_2)

# %%
type(df_ted_2)
# Out:
# pandas.core.frame.DataFrame

# %%
df_ted_2.tail(5)
# Out:
#                       views
# main_speaker
# Ziauddin Yousafzai  2124521
# Ziyah Gafić        1000194
# Zubaida Bai          801279
# eL Seed             2220042
# iO Tillett Wright   2679698

# %%
df_ted.drop(columns = 'total_view')[:5]
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event   film_date  languages   main_speaker  \
# 0  TED2006  1140825600         60   Ken Robinson
# 1  TED2006  1140825600         43        Al Gore
# 2  TED2006  1140739200         26    David Pogue
# 3  TED2006  1140912000         35  Majora Carter
# 4  TED2006  1140566400         48   Hans Rosling
#
#                                             name  num_speaker  published_date  \
# 0      Ken Robinson: Do schools kill creativity?            1      1151367060
# ...

# %%
df_ted = pd.merge(df_ted, df_ted_2, on = ['main_speaker'])

# %%
df_ted.drop(columns = 'total_view')[:5]
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1      1234  In this poignant, funny follow-up to his fable...      1008
# 2       473  In this talk from RSA Animate, Sir Ken Robinso...       700
# 3       634  Sir Ken Robinson outlines 3 principles crucial...      1151
# 4       265  With the same humor and humanity he exuded in ...       977
#
#                  event   film_date  languages  main_speaker  \
# 0              TED2006  1140825600         60  Ken Robinson
# 1              TED2010  1265414400         57  Ken Robinson
# 2          RSA Animate  1287014400          0  Ken Robinson
# 3  TED Talks Education  1366675200         43  Ken Robinson
# 4              TED2006  1140825600         43       Al Gore
#
#                                                 name  num_speaker  \
# 0          Ken Robinson: Do schools kill creativity?            1
# ...

# %%
#graph popular speaker by total views
graph_2 = sns.barplot(y = 'main_speaker', x = 'views_y', data = df_ted.sort_values('views_y', ascending = False) [:20])
# Out:
# /root/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df_ted = df_ted.drop(columns = 'total_view')

# %%
df_ted.tail(3)
# Out:
#       comments                                        description  duration  \
# 2547        10  Science fiction visions of the future show us ...       651
# 2548        32  In an unmissable talk about race and politics ...      1100
# 2549         8  With more than half of the world population li...       519
#
#              event   film_date  languages       main_speaker  \
# 2547       TED2017  1492992000          1     Radhika Nagpal
# 2548  TEDxMileHigh  1499472000          1   Theo E.J. Wilson
# 2549       TED2017  1492992000          1  Karoliina Korppoo
#
#                                                    name  num_speaker  \
# 2547  Radhika Nagpal: What intelligent machines can ...            1
# 2548  Theo E.J. Wilson: A black man goes undercover ...            1
# 2549  Karoliina Korppoo: How a video game might help...            1
#
#       published_date                                            ratings  \
# ...

# %%
df_ted = df_ted.rename(columns = {'views_x': 'views', 'views_y': 'total_view'})

# %%
df_ted.tail(3)
# Out:
#       comments                                        description  duration  \
# 2547        10  Science fiction visions of the future show us ...       651
# 2548        32  In an unmissable talk about race and politics ...      1100
# 2549         8  With more than half of the world population li...       519
#
#              event   film_date  languages       main_speaker  \
# 2547       TED2017  1492992000          1     Radhika Nagpal
# 2548  TEDxMileHigh  1499472000          1   Theo E.J. Wilson
# 2549       TED2017  1492992000          1  Karoliina Korppoo
#
#                                                    name  num_speaker  \
# 2547  Radhika Nagpal: What intelligent machines can ...            1
# 2548  Theo E.J. Wilson: A black man goes undercover ...            1
# 2549  Karoliina Korppoo: How a video game might help...            1
#
#       published_date                                            ratings  \
# ...

# %%
#plot distribution of views
sns.distplot(df_ted[df_ted['views'] < 0.4e7]['views'])
# Out:
# /root/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#plot distribution of comment
sns.distplot(df_ted[df_ted['comments'] < 1000]['comments'])
# Out:
# /root/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df_ted['film_date'] = pd.to_datetime(df_ted['film_date'])

# %%
df_ted['published_date'] = pd.to_datetime(df_ted['published_date'], unit= 's')

# %%
df_ted.tail(3)
# Out:
#       comments                                        description  duration  \
# 2547        10  Science fiction visions of the future show us ...       651
# 2548        32  In an unmissable talk about race and politics ...      1100
# 2549         8  With more than half of the world population li...       519
#
#              event           film_date  languages       main_speaker  \
# 2547       TED2017 2017-09-21 15:01:35          1     Radhika Nagpal
# 2548  TEDxMileHigh 2017-09-21 20:00:42          1   Theo E.J. Wilson
# 2549       TED2017 2017-09-22 15:00:22          1  Karoliina Korppoo
#
#                                                    name  num_speaker  \
# 2547  Radhika Nagpal: What intelligent machines can ...            1
# 2548  Theo E.J. Wilson: A black man goes undercover ...            1
# 2549  Karoliina Korppoo: How a video game might help...            1
#
#                     published_date  \
# 2547 1970-01-01 00:00:01.506006095
# ...

# %%
import datetime as dt

# %%
df_ted['film_date'] = df_ted['film_date'].dt.date

# %%
df_ted['published_date']= df_ted['published_date'].dt.date

# %%
df_ted.tail(1)
# Out:
#       comments                                        description  duration  \
# 2549         8  With more than half of the world population li...       519
#
#         event   film_date  languages       main_speaker  \
# 2549  TED2017  2017-09-22          1  Karoliina Korppoo
#
#                                                    name  num_speaker  \
# 2549  Karoliina Korppoo: How a video game might help...            1
#
#      published_date                                            ratings  \
# 2549     1970-01-01  [{'id': 21, 'name': 'Unconvincing', 'count': 2...
#
#                                           related_talks speaker_occupation  \
# 2549  [{'id': 2682, 'hero': 'https://pe.tedcdn.com/i...      Game designer
#
#                                                    tags  \
# 2549  ['cities', 'design', 'future', 'infrastructure...
#
#                                                   title  \
# 2549  How a video game might help us build better ci...
#
# ...

# %%
#correlation between views and duration
graph_3 = sns.jointplot(x = 'views', y = 'duration', data = df_ted)
graph_3 = graph_3.annotate(stats.pearsonr)
# Out:
# /root/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /root/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
from scipy import stats

# %%
#because p-value is really low. we can tell that there isn't strong correlation between views and duration
#hence we can take a look at another indicator, views and comments to see if they go hand in hand 
#check correlation between views and comment
graph_4 = sns.jointplot(x = 'views', y= 'comments', data = df_ted)
graph_4 = graph_4.annotate(stats.pearsonr)
#p-value reveals there is strong correlation between views and comments
# Out:
# /root/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# /root/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
df_ted.tail(1)
# Out:
#       comments                                        description  duration  \
# 2549         8  With more than half of the world population li...       519
#
#         event  film_date  languages       main_speaker  \
# 2549  TED2017 2017-09-22          1  Karoliina Korppoo
#
#                                                    name  num_speaker  \
# 2549  Karoliina Korppoo: How a video game might help...            1
#
#      published_date                                            ratings  \
# 2549     1970-01-01  [{'id': 21, 'name': 'Unconvincing', 'count': 2...
#
#                                           related_talks speaker_occupation  \
# 2549  [{'id': 2682, 'hero': 'https://pe.tedcdn.com/i...      Game designer
#
#                                                    tags  \
# 2549  ['cities', 'design', 'future', 'infrastructure...
#
#                                                   title  \
# 2549  How a video game might help us build better ci...
#
# ...

# %%
df_ted.dtypes
# Out:
# comments                       int64
# description                   object
# duration                       int64
# event                         object
# film_date             datetime64[ns]
# languages                      int64
# main_speaker                  object
# name                          object
# num_speaker                    int64
# published_date        datetime64[ns]
# ratings                       object
# related_talks                 object
# speaker_occupation            object
# tags                          object
# title                         object
# url                           object
# views                          int64
# total_view                     int64
# day_of_week                   object
# dtype: object

# %%
df_ted['film_date'] = pd.to_datetime(df_ted['film_date'])

# %%
df_ted['published_date']= pd.to_datetime(df_ted['published_date'])

# %%
df_ted['day_of_week']= df_ted['film_date'].dt.day_name()

# %%
#check which published day produce the most views
graph_4 = sns.barplot(x= 'day_of_week', y= 'total_view', data = df_ted.sort_values('total_view', ascending = False))
#graph_2 = sns.barplot(y = 'main_speaker', x = 'views_y', data = df_ted.sort_values('views_y', ascending = False) [:20])
# Out:
# /root/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
df_ted_mini = df_ted.groupby(['day_of_week'])['views'].agg(sum)

# %%
df_ted_mini.reset_index()
# Out:
#   day_of_week      views
# 0      Friday  913743178
# 1      Monday  759650746
# 2    Saturday   39517148
# 3      Sunday   59198670
# 4    Thursday  782475328
# 5     Tuesday  934930373
# 6   Wednesday  841143135

# %%
for col in df_ted_mini.columns:
    print(col)
# Out:
# views

# %%
df_ted_mini.columns
# Out:
# Index(['views'], dtype='object')
